# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "4"

# %%
from core.trainer import train_toy_model
from core.visualisation import visualize_interference

# %%
trained_state, trained_model = train_toy_model(
    num_features=20, hidden_dim=5, sparsity=0.99
)
visualize_interference(trained_state)
# Out:
# Step 0 | Loss: 0.0224
# Step 1000 | Loss: 0.0040
# Step 2000 | Loss: 0.0027
# Step 3000 | Loss: 0.0032
# Step 4000 | Loss: 0.0033

# %%
trained_state, trained_model = train_toy_model(
    num_features=20, hidden_dim=20, sparsity=0, steps=10000
)
visualize_interference(trained_state)
# Out:
# Step 0 | Loss: 3.6698
# Step 1000 | Loss: 0.0340
# Step 2000 | Loss: 0.0004
# Step 3000 | Loss: 0.0000
# Step 4000 | Loss: 0.0000
# Step 5000 | Loss: 0.0000
# Step 6000 | Loss: 0.0000
# Step 7000 | Loss: 0.0000
# Step 8000 | Loss: 0.0000
# Step 9000 | Loss: 0.0000

# %%
trained_state, trained_model = train_toy_model(
    num_features=20, hidden_dim=20, sparsity=0.99, steps=10000
)
visualize_interference(trained_state)
# Out:
# Step 0 | Loss: 0.0242
# Step 1000 | Loss: 0.0001
# Step 2000 | Loss: 0.0000
# Step 3000 | Loss: 0.0000
# Step 4000 | Loss: 0.0000
# Step 5000 | Loss: 0.0000
# Step 6000 | Loss: 0.0000
# Step 7000 | Loss: 0.0000
# Step 8000 | Loss: 0.0000
# Step 9000 | Loss: 0.0000

# %%
from core.trainer import train_toy_model_with_history
from core.visualisation import visualize_interference_over_time

# %%
trained_state, weight_history = train_toy_model_with_history(num_features=20, hidden_dim=5, sparsity=0, steps=5000*2)
visualize_interference_over_time(weight_history)
# Out:
# Step    0 | Loss: 1.7487
# Step 1000 | Loss: 0.4125
# Step 2000 | Loss: 0.3933
# Step 3000 | Loss: 0.3910
# Step 4000 | Loss: 0.3887
# Step 5000 | Loss: 0.3933
# Step 6000 | Loss: 0.3958
# Step 7000 | Loss: 0.3914
# Step 8000 | Loss: 0.3904
# Step 9000 | Loss: 0.3929

# %%
trained_state, weight_history = train_toy_model_with_history(num_features=20, hidden_dim=20, sparsity=0, steps=5000*2)
visualize_interference_over_time(weight_history)
# Out:
# Step    0 | Loss: 3.6698
# Step 1000 | Loss: 0.0029
# Step 2000 | Loss: 0.0000
# Step 3000 | Loss: 0.0000
# Step 4000 | Loss: 0.0000
# Step 5000 | Loss: 0.0000
# Step 6000 | Loss: 0.0000
# Step 7000 | Loss: 0.0000
# Step 8000 | Loss: 0.0000
# Step 9000 | Loss: 0.0000

# %%
trained_state, weight_history = train_toy_model_with_history(num_features=20, hidden_dim=5, sparsity=0.5, steps=5000)
visualize_interference_over_time(weight_history)
# Out:
# Step    0 | Loss: 0.9859
# Step 1000 | Loss: 0.4767
# Step 2000 | Loss: 0.4554
# Step 3000 | Loss: 0.4665
# Step 4000 | Loss: 0.4525

# %%
trained_state, weight_history = train_toy_model_with_history(num_features=20, hidden_dim=5, sparsity=0.75, steps=5000)
visualize_interference_over_time(weight_history)
# Out:
# Step    0 | Loss: 0.5039
# Step 1000 | Loss: 0.2144
# Step 2000 | Loss: 0.2135
# Step 3000 | Loss: 0.2134
# Step 4000 | Loss: 0.2107

# %%
trained_state, weight_history = train_toy_model_with_history(num_features=20, hidden_dim=5, sparsity=0.99, steps=5000)
visualize_interference_over_time(weight_history)
# Out:
# Step    0 | Loss: 0.0224
# Step 1000 | Loss: 0.0040
# Step 2000 | Loss: 0.0027
# Step 3000 | Loss: 0.0031
# Step 4000 | Loss: 0.0032

# %%
from core.trainer import train_correlated_toy_model_with_history

# %%
trained_state, weight_history = train_correlated_toy_model_with_history(num_features=20, hidden_dim=5, sparsity=0.99, steps=5000)
visualize_interference_over_time(weight_history)
# Out:
# Step    0 | Loss: 0.0440
# Step 1000 | Loss: 0.0049
# Step 2000 | Loss: 0.0049
# Step 3000 | Loss: 0.0047
# Step 4000 | Loss: 0.0061

# %%
trained_state, weight_history = train_correlated_toy_model_with_history(num_features=20, hidden_dim=20, sparsity=0.99, steps=5000)
visualize_interference_over_time(weight_history)
# Out:
# Step    0 | Loss: 0.0288
# Step 1000 | Loss: 0.0000
# Step 2000 | Loss: 0.0000
# Step 3000 | Loss: 0.0000
# Step 4000 | Loss: 0.0000
